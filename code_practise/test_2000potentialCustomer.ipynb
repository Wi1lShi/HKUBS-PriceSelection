# %%
from group_project import decision_table

# %%
df = decision_table(n=2000)
df.final_results(step=0.01)
# Out:
# Price: 3.0 done!, Consumer Count: 1371, Total Revenue: 4113.0, Average Revenue: 2.0565
# Price: 3.01 done!, Consumer Count: 1357, Total Revenue: 4084.5699999999997, Average Revenue: 2.0422849999999997
# Price: 3.0199999999999996 done!, Consumer Count: 1386, Total Revenue: 4185.719999999999, Average Revenue: 2.0928599999999995
# Price: 3.0299999999999994 done!, Consumer Count: 1415, Total Revenue: 4287.449999999999, Average Revenue: 2.1437249999999994
# Price: 3.039999999999999 done!, Consumer Count: 1311, Total Revenue: 3985.4399999999987, Average Revenue: 1.9927199999999994
# Price: 3.049999999999999 done!, Consumer Count: 1373, Total Revenue: 4187.649999999999, Average Revenue: 2.0938249999999994
# Price: 3.0599999999999987 done!, Consumer Count: 1325, Total Revenue: 4054.499999999998, Average Revenue: 2.027249999999999
# Price: 3.0699999999999985 done!, Consumer Count: 1267, Total Revenue: 3889.6899999999982, Average Revenue: 1.944844999999999
# ...

# %%
df.final_plot()

# %%
df.average_revenue_plot()

# %%
df.customer_plot()

# %%
df.revenue_plot()

# %%
max_price = df.final_DF[(df.final_DF['Price'] < 7) & (df.final_DF['Price'] > 6)].sort_values('Total Revenue', ascending=False)[0:20]['Price']

# %%
# draw histogram of the max_price
import matplotlib.pyplot as plt

plt.hist(max_price, bins=20)
# Out:
# (array([3., 0., 2., 2., 0., 2., 0., 1., 1., 1., 1., 2., 0., 0., 1., 0., 1.,
#         1., 1., 1.]),
#  array([6.01, 6.05, 6.09, 6.13, 6.17, 6.21, 6.25, 6.29, 6.33, 6.37, 6.41,
#         6.45, 6.49, 6.53, 6.57, 6.61, 6.65, 6.69, 6.73, 6.77, 6.81]),
#  <BarContainer object of 20 artists>)

# %%
# get the median fo the max_price
import statistics
statistics.median(max_price)
# Out:
# 6.319999999999929
